# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\vasanth\appdata\local\programs\python\python38\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\vasanth\appdata\local\programs\python\python38\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\vasanth\appdata\local\programs\python\python38\lib\site-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\vasanth\appdata\local\programs\python\python38\lib\site-packages (from nltk) (2024.4.16)
# Requirement already satisfied: tqdm in c:\users\vasanth\appdata\local\programs\python\python38\lib\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: colorama in c:\users\vasanth\appdata\local\programs\python\python38\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
import numpy as np
import json
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vasanth\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\vasanth\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Load data from bot.json
with open('bot2.json', 'r') as file:
    data = json.load(file)

# %%
# Initialize WordNet Lemmatizer
lemmatizer = WordNetLemmatizer()

# Initialize lists for storing words, classes, and training data
words = []
classes = []
documents = []
ignore_words = ['?', '!']

# %%
# Preprocess data, tokenize words, lemmatize, create bag of words
for intent in data['intents']:
    for pattern in intent['patterns']:
        # Tokenize words
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # Add documents
        documents.append((w, intent['tag']))
        # Add unique classes
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# Lemmatize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# Sort classes
classes = sorted(list(set(classes)))

print(len(documents), "documents")
print(len(classes), "classes", classes)
print(len(words), "unique lemmatized words", words)
# Out:
# 179 documents
# 39 classes ['My age is 20s', 'My age is 25s', 'My age is 30', 'My age is 35', 'My age is 40', 'My age is 50_plus', 'aps_workout', 'arms_workout', 'general_fitness', 'goodbye', 'greeting', 'gym_workouts_for_elderly', 'handball_info', 'high_calorie_foods', 'low_calorie_foods', 'masturbation workout disadvantages', 'my age is 10s', 'my age is 15s', 'my age is 6s', 'no_equipment_glutes_workouts', 'no_equipment_hamstrings_workouts', 'no_equipment_lats_workouts', 'no_equipment_quads_workouts', 'no_equipment_traps_workouts', 'non_veg_fitness', 'nutrients_for_fitness', 'pregnancy_gym_workouts', 'pregnancy_workouts', 'shoulder_workout', 'spa_benefits', 'terms_and_conditions', 'vitamins_for_fitness', 'weight_gain_diet', 'weight_gain_workouts', 'weight_loss_diet', 'weight_loss_workouts', 'workout_nutrition', 'workouts_for_elderly', 'wrestling_evaluation']
# 211 unique lemmatized words ['10', '15', '20', '25', '30', '35', '40', '50_plus', '6', '70', 'a', 'activity', 'advantage', 'advice', 'after', 'age', 'ai', 'and', 'anxiety', 'aps', 'are', 'arm', 'at', 'avoid', 'avoiding', 'bad', 'before', 'beginner', 'benefit', 'best', 'biceps', 'body', 'build', 'burn', 'busy', 'bye', 'calcium-rich', 'calm', 'calorie', 'calorie-dense', 'can', 'cardio', 'chatbot', 'child', 'class', 'condition', 'controlling', 'cool-down', 'count', 'day', 'dealing', 'diet', 'dieting', 'disadvantage', 'do', 'doe', 'during', 'eat', 'effective', 'elderly', 'enthusiast', 'equipment', 'essential', 'exercise', 'exercising', 'expectant', 'fat', 'fitness', 'flexibility', 'food', 'for', 'fruit', 'gain', 'general', 'glute', 'goal', 'good', 'goodbye', 'group', 'growth', 'gym', 'hamstring', 'handball', 'healthcare', 'healthy', 'hello', 'hey', 'hi', 'high', 'high-calorie', 'high-protein', 'hiit', 'hiring', 'home', 'how', 'hydration', 'importance', 'improve', 'improving', 'in', 'incorporating', 'increasing', 'information', 'injury', 'inner', 'intake', 'into', 'is', 'item', 'lat', 'later', 'lose', 'loss', 'low', 'low-calorie', 'low-carb', 'male', 'many', 'masturbation', 'meal', 'measuring', 'meat', 'medical', 'men', 'mother', 'motivation', 'muscle', 'muscle-building', 'my', 'no-equipment', 'non-vegetarian', 'nutrient', 'nutrition', 'of', 'old', 'option', 'or', 'outdoor', 'personal', 'planning', 'plateau', 'play', 'portion', 'post', 'post-workout', 'posture', 'pre', 'pregnancy', 'pregnant', 'prevent', 'progress', 'promote', 'protein', 'quad', 'recovery', 'regularly', 'relieving', 'rep', 'replace', 'rest', 'risk', 'role', 'routine', 'rule', 'safe', 'schedule', 'seafood', 'see', 'senior', 'set', 'should', 'shoulder', 'sleep', 'source', 'spa', 'sport', 'strength', 'strengthen', 'strengthening', 'stress', 'stretching', 'supplement', 'term', 'the', 'through', 'time', 'tip', 'to', 'tone', 'tracking', 'trainer', 'training', 'trap', 'treatment', 'triceps', 'up', 'vegetable', 'vitamin', 'vitamin-rich', 'vs.', 'warm', 'weight', 'what', 'while', 'with', 'without', 'woman', 'workout', 'wrestling', 'year', 'you']

# %%
# Save words and classes to pickle files for later use
import pickle
pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

# %%
# Create training data
training = []
output_empty = [0] * len(classes)

for doc in documents:
    # Initialize bag of words
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # Create bag of words array
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # Output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# Shuffle the training data
random.shuffle(training)

# Separate features and labels
train_x = np.array([sample[0] for sample in training])
train_y = np.array([sample[1] for sample in training])

# Define and compile the model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.summary()

# Train the model
hist = model.fit(train_x, train_y, epochs=200, batch_size=5, verbose=1)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 128)               27136
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 39)                2535
#
# =================================================================
# Total params: 37927 (148.15 KB)
# Trainable params: 37927 (148.15 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/200
# 36/36 [==============================] - 3s 24ms/step - loss: 3.6115 - accuracy: 0.1173
# Epoch 2/200
# 36/36 [==============================] - 1s 25ms/step - loss: 3.4173 - accuracy: 0.1788
# Epoch 3/200
# 36/36 [==============================] - 1s 18ms/step - loss: 3.2673 - accuracy: 0.1788
# Epoch 4/200
# 36/36 [==============================] - 1s 18ms/step - loss: 3.1549 - accuracy: 0.1844
# Epoch 5/200
# 36/36 [==============================] - 1s 18ms/step - loss: 3.0043 - accuracy: 0.2179
# Epoch 6/200
# 36/36 [==============================] - 1s 16ms/step - loss: 2.8291 - accuracy: 0.2458
# Epoch 7/200
# 36/36 [==============================] - 1s 20ms/step - loss: 2.6003 - accuracy: 0.2849
# Epoch 8/200
# 36/36 [==============================] - 1s 17ms/step - loss: 2.4781 - accuracy: 0.3128
# Epoch 9/200
# 36/36 [==============================] - 1s 19ms/step - loss: 2.2842 - accuracy: 0.3687
# Epoch 10/200
# 36/36 [==============================] - 1s 17ms/step - loss: 2.1460 - accuracy: 0.3855
# Epoch 11/200
# 36/36 [==============================] - 1s 22ms/step - loss: 2.0529 - accuracy: 0.3966
# Epoch 12/200
# 36/36 [==============================] - 1s 34ms/step - loss: 1.9131 - accuracy: 0.4637
# Epoch 13/200
# 36/36 [==============================] - 1s 21ms/step - loss: 1.9187 - accuracy: 0.4581
# Epoch 14/200
# 36/36 [==============================] - 1s 24ms/step - loss: 1.6642 - accuracy: 0.5531
# Epoch 15/200
# 36/36 [==============================] - 1s 20ms/step - loss: 1.6074 - accuracy: 0.5307
# Epoch 16/200
# 36/36 [==============================] - 1s 17ms/step - loss: 1.6337 - accuracy: 0.5251
# Epoch 17/200
# 36/36 [==============================] - 1s 18ms/step - loss: 1.3763 - accuracy: 0.5978
# Epoch 18/200
# 36/36 [==============================] - 1s 18ms/step - loss: 1.5008 - accuracy: 0.5419
# Epoch 19/200
# 36/36 [==============================] - 1s 21ms/step - loss: 1.1217 - accuracy: 0.6872
# Epoch 20/200
# 36/36 [==============================] - 1s 28ms/step - loss: 1.2343 - accuracy: 0.6201
# Epoch 21/200
# 36/36 [==============================] - 1s 28ms/step - loss: 1.0606 - accuracy: 0.6816
# Epoch 22/200
# 36/36 [==============================] - 1s 31ms/step - loss: 1.0226 - accuracy: 0.6983
# Epoch 23/200
# 36/36 [==============================] - 1s 31ms/step - loss: 0.9892 - accuracy: 0.7263
# Epoch 24/200
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8762 - accuracy: 0.7598
# Epoch 25/200
# 36/36 [==============================] - 1s 23ms/step - loss: 0.8591 - accuracy: 0.7542
# Epoch 26/200
# 36/36 [==============================] - 1s 22ms/step - loss: 0.8868 - accuracy: 0.7374
# Epoch 27/200
# 36/36 [==============================] - 1s 25ms/step - loss: 0.8538 - accuracy: 0.7151
# Epoch 28/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.8330 - accuracy: 0.7542
# Epoch 29/200
# 36/36 [==============================] - 1s 29ms/step - loss: 0.7661 - accuracy: 0.7877
# Epoch 30/200
# 36/36 [==============================] - 1s 18ms/step - loss: 0.8062 - accuracy: 0.7654
# Epoch 31/200
# 36/36 [==============================] - 1s 29ms/step - loss: 0.7428 - accuracy: 0.7989
# Epoch 32/200
# 36/36 [==============================] - 1s 34ms/step - loss: 0.7692 - accuracy: 0.7486
# Epoch 33/200
# 36/36 [==============================] - 1s 25ms/step - loss: 0.7166 - accuracy: 0.7933
# Epoch 34/200
# 36/36 [==============================] - 1s 27ms/step - loss: 0.6323 - accuracy: 0.8380
# Epoch 35/200
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6788 - accuracy: 0.7877
# Epoch 36/200
# 36/36 [==============================] - 1s 27ms/step - loss: 0.5357 - accuracy: 0.8492
# Epoch 37/200
# 36/36 [==============================] - 1s 25ms/step - loss: 0.5100 - accuracy: 0.8827
# Epoch 38/200
# 36/36 [==============================] - 1s 27ms/step - loss: 0.5343 - accuracy: 0.8324
# Epoch 39/200
# 36/36 [==============================] - 1s 27ms/step - loss: 0.6152 - accuracy: 0.8101
# Epoch 40/200
# 36/36 [==============================] - 1s 38ms/step - loss: 0.5917 - accuracy: 0.8101
# Epoch 41/200
# 36/36 [==============================] - 1s 29ms/step - loss: 0.6480 - accuracy: 0.8045
# Epoch 42/200
# 36/36 [==============================] - 1s 24ms/step - loss: 0.5295 - accuracy: 0.8268
# Epoch 43/200
# 36/36 [==============================] - 1s 22ms/step - loss: 0.5112 - accuracy: 0.8324
# Epoch 44/200
# 36/36 [==============================] - 1s 22ms/step - loss: 0.4752 - accuracy: 0.8324
# Epoch 45/200
# 36/36 [==============================] - 1s 16ms/step - loss: 0.5706 - accuracy: 0.8380
# Epoch 46/200
# 36/36 [==============================] - 1s 16ms/step - loss: 0.5318 - accuracy: 0.8324
# Epoch 47/200
# 36/36 [==============================] - 1s 28ms/step - loss: 0.4218 - accuracy: 0.8659
# Epoch 48/200
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4712 - accuracy: 0.8436
# Epoch 49/200
# 36/36 [==============================] - 1s 19ms/step - loss: 0.4754 - accuracy: 0.8659
# Epoch 50/200
# 36/36 [==============================] - 1s 20ms/step - loss: 0.4425 - accuracy: 0.8827
# Epoch 51/200
# 36/36 [==============================] - 1s 20ms/step - loss: 0.3781 - accuracy: 0.8883
# Epoch 52/200
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4430 - accuracy: 0.8492
# Epoch 53/200
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4469 - accuracy: 0.8324
# Epoch 54/200
# 36/36 [==============================] - 1s 22ms/step - loss: 0.4270 - accuracy: 0.8715
# Epoch 55/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.3962 - accuracy: 0.8771
# Epoch 56/200
# 36/36 [==============================] - 1s 31ms/step - loss: 0.3314 - accuracy: 0.8994
# Epoch 57/200
# 36/36 [==============================] - 1s 22ms/step - loss: 0.3304 - accuracy: 0.9106
# Epoch 58/200
# 36/36 [==============================] - 1s 17ms/step - loss: 0.3784 - accuracy: 0.8603
# Epoch 59/200
# 36/36 [==============================] - 1s 19ms/step - loss: 0.2588 - accuracy: 0.9218
# Epoch 60/200
# 36/36 [==============================] - 1s 28ms/step - loss: 0.4506 - accuracy: 0.8771
# Epoch 61/200
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4015 - accuracy: 0.8883
# Epoch 62/200
# 36/36 [==============================] - 1s 18ms/step - loss: 0.3251 - accuracy: 0.8994
# Epoch 63/200
# 36/36 [==============================] - 1s 19ms/step - loss: 0.3333 - accuracy: 0.8939
# Epoch 64/200
# 36/36 [==============================] - 1s 18ms/step - loss: 0.3114 - accuracy: 0.8827
# Epoch 65/200
# 36/36 [==============================] - 1s 22ms/step - loss: 0.3271 - accuracy: 0.8994
# Epoch 66/200
# 36/36 [==============================] - 1s 28ms/step - loss: 0.3065 - accuracy: 0.8827
# Epoch 67/200
# 36/36 [==============================] - 1s 18ms/step - loss: 0.3518 - accuracy: 0.8827
# Epoch 68/200
# 36/36 [==============================] - 1s 20ms/step - loss: 0.3108 - accuracy: 0.9218
# Epoch 69/200
# 36/36 [==============================] - 1s 27ms/step - loss: 0.2946 - accuracy: 0.8994
# Epoch 70/200
# 36/36 [==============================] - 1s 20ms/step - loss: 0.2720 - accuracy: 0.8994
# Epoch 71/200
# 36/36 [==============================] - 1s 20ms/step - loss: 0.3034 - accuracy: 0.9162
# Epoch 72/200
# 36/36 [==============================] - 1s 25ms/step - loss: 0.2674 - accuracy: 0.9330
# Epoch 73/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.3239 - accuracy: 0.8827
# Epoch 74/200
# 36/36 [==============================] - 1s 17ms/step - loss: 0.2661 - accuracy: 0.9106
# Epoch 75/200
# 36/36 [==============================] - 1s 27ms/step - loss: 0.3351 - accuracy: 0.8827
# Epoch 76/200
# 36/36 [==============================] - 1s 29ms/step - loss: 0.2607 - accuracy: 0.9050
# Epoch 77/200
# 36/36 [==============================] - 1s 26ms/step - loss: 0.3129 - accuracy: 0.8994
# Epoch 78/200
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2294 - accuracy: 0.9385
# Epoch 79/200
# 36/36 [==============================] - 1s 23ms/step - loss: 0.2208 - accuracy: 0.9330
# Epoch 80/200
# 36/36 [==============================] - 1s 23ms/step - loss: 0.2707 - accuracy: 0.9162
# Epoch 81/200
# 36/36 [==============================] - 1s 29ms/step - loss: 0.3467 - accuracy: 0.9106
# Epoch 82/200
# 36/36 [==============================] - 1s 40ms/step - loss: 0.2638 - accuracy: 0.9218
# Epoch 83/200
# 36/36 [==============================] - 1s 27ms/step - loss: 0.2796 - accuracy: 0.9218
# Epoch 84/200
# 36/36 [==============================] - 1s 36ms/step - loss: 0.3101 - accuracy: 0.9050
# Epoch 85/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.3108 - accuracy: 0.9106
# Epoch 86/200
# 36/36 [==============================] - 1s 30ms/step - loss: 0.2594 - accuracy: 0.9330
# Epoch 87/200
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2846 - accuracy: 0.9274
# Epoch 88/200
# 36/36 [==============================] - 1s 23ms/step - loss: 0.3027 - accuracy: 0.8994
# Epoch 89/200
# 36/36 [==============================] - 1s 24ms/step - loss: 0.3168 - accuracy: 0.8827
# Epoch 90/200
# 36/36 [==============================] - 1s 32ms/step - loss: 0.2644 - accuracy: 0.9162
# Epoch 91/200
# 36/36 [==============================] - 1s 28ms/step - loss: 0.2469 - accuracy: 0.9330
# Epoch 92/200
# 36/36 [==============================] - 1s 34ms/step - loss: 0.3015 - accuracy: 0.9274
# Epoch 93/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.2213 - accuracy: 0.9330
# Epoch 94/200
# 36/36 [==============================] - 1s 23ms/step - loss: 0.2267 - accuracy: 0.9218
# Epoch 95/200
# 36/36 [==============================] - 1s 27ms/step - loss: 0.2499 - accuracy: 0.9218
# Epoch 96/200
# 36/36 [==============================] - 1s 16ms/step - loss: 0.3116 - accuracy: 0.8883
# Epoch 97/200
# 36/36 [==============================] - 1s 24ms/step - loss: 0.3095 - accuracy: 0.8939
# Epoch 98/200
# 36/36 [==============================] - 1s 23ms/step - loss: 0.2845 - accuracy: 0.9162
# Epoch 99/200
# 36/36 [==============================] - 1s 17ms/step - loss: 0.2637 - accuracy: 0.8883
# Epoch 100/200
# 36/36 [==============================] - 1s 31ms/step - loss: 0.2871 - accuracy: 0.8994
# Epoch 101/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.2734 - accuracy: 0.9162
# Epoch 102/200
# 36/36 [==============================] - 1s 22ms/step - loss: 0.1637 - accuracy: 0.9497
# Epoch 103/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.2156 - accuracy: 0.9330
# Epoch 104/200
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2263 - accuracy: 0.9385
# Epoch 105/200
# 36/36 [==============================] - 1s 33ms/step - loss: 0.1787 - accuracy: 0.9441
# Epoch 106/200
# 36/36 [==============================] - 1s 25ms/step - loss: 0.1892 - accuracy: 0.9330
# Epoch 107/200
# 36/36 [==============================] - 1s 23ms/step - loss: 0.1983 - accuracy: 0.9330
# Epoch 108/200
# 36/36 [==============================] - 1s 26ms/step - loss: 0.2171 - accuracy: 0.9385
# Epoch 109/200
# 36/36 [==============================] - 1s 22ms/step - loss: 0.1969 - accuracy: 0.9330
# Epoch 110/200
# 36/36 [==============================] - 1s 18ms/step - loss: 0.2210 - accuracy: 0.9385
# Epoch 111/200
# 36/36 [==============================] - 1s 23ms/step - loss: 0.2296 - accuracy: 0.9441
# Epoch 112/200
# 36/36 [==============================] - 1s 28ms/step - loss: 0.1807 - accuracy: 0.9497
# Epoch 113/200
# 36/36 [==============================] - 1s 16ms/step - loss: 0.2106 - accuracy: 0.9441
# Epoch 114/200
# 36/36 [==============================] - 1s 16ms/step - loss: 0.2397 - accuracy: 0.9106
# Epoch 115/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1562 - accuracy: 0.9609
# Epoch 116/200
# 36/36 [==============================] - 1s 27ms/step - loss: 0.2365 - accuracy: 0.9106
# Epoch 117/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1845 - accuracy: 0.9441
# Epoch 118/200
# 36/36 [==============================] - 1s 25ms/step - loss: 0.1571 - accuracy: 0.9385
# Epoch 119/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1744 - accuracy: 0.9385
# Epoch 120/200
# 36/36 [==============================] - 1s 32ms/step - loss: 0.1815 - accuracy: 0.9553
# Epoch 121/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1354 - accuracy: 0.9665
# Epoch 122/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.0907 - accuracy: 0.9832
# Epoch 123/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1561 - accuracy: 0.9553
# Epoch 124/200
# 36/36 [==============================] - 1s 31ms/step - loss: 0.1430 - accuracy: 0.9609
# Epoch 125/200
# 36/36 [==============================] - 1s 26ms/step - loss: 0.1095 - accuracy: 0.9665
# Epoch 126/200
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2131 - accuracy: 0.9441
# Epoch 127/200
# 36/36 [==============================] - 1s 23ms/step - loss: 0.1295 - accuracy: 0.9665
# Epoch 128/200
# 36/36 [==============================] - 1s 38ms/step - loss: 0.1286 - accuracy: 0.9553
# Epoch 129/200
# 36/36 [==============================] - 1s 19ms/step - loss: 0.2304 - accuracy: 0.9162
# Epoch 130/200
# 36/36 [==============================] - 1s 25ms/step - loss: 0.1549 - accuracy: 0.9497
# Epoch 131/200
# 36/36 [==============================] - 1s 26ms/step - loss: 0.1604 - accuracy: 0.9553
# Epoch 132/200
# 36/36 [==============================] - 1s 27ms/step - loss: 0.1810 - accuracy: 0.9385
# Epoch 133/200
# 36/36 [==============================] - 1s 35ms/step - loss: 0.2046 - accuracy: 0.9330
# Epoch 134/200
# 36/36 [==============================] - 1s 26ms/step - loss: 0.1646 - accuracy: 0.9497
# Epoch 135/200
# 36/36 [==============================] - 1s 31ms/step - loss: 0.1759 - accuracy: 0.9385
# Epoch 136/200
# 36/36 [==============================] - 1s 35ms/step - loss: 0.1583 - accuracy: 0.9497
# Epoch 137/200
# 36/36 [==============================] - 1s 30ms/step - loss: 0.1939 - accuracy: 0.9497
# Epoch 138/200
# 36/36 [==============================] - 2s 48ms/step - loss: 0.1882 - accuracy: 0.9441
# Epoch 139/200
# 36/36 [==============================] - 2s 50ms/step - loss: 0.1909 - accuracy: 0.9609
# Epoch 140/200
# 36/36 [==============================] - 1s 38ms/step - loss: 0.1828 - accuracy: 0.9497
# Epoch 141/200
# 36/36 [==============================] - 2s 51ms/step - loss: 0.1130 - accuracy: 0.9832
# Epoch 142/200
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1724 - accuracy: 0.9330
# Epoch 143/200
# 36/36 [==============================] - 1s 31ms/step - loss: 0.1718 - accuracy: 0.9385
# Epoch 144/200
# 36/36 [==============================] - 1s 33ms/step - loss: 0.1054 - accuracy: 0.9777
# Epoch 145/200
# 36/36 [==============================] - 1s 42ms/step - loss: 0.1501 - accuracy: 0.9553
# Epoch 146/200
# 36/36 [==============================] - 2s 58ms/step - loss: 0.1587 - accuracy: 0.9330
# Epoch 147/200
# 36/36 [==============================] - 1s 36ms/step - loss: 0.2049 - accuracy: 0.9330
# Epoch 148/200
# 36/36 [==============================] - 2s 55ms/step - loss: 0.1551 - accuracy: 0.9553
# Epoch 149/200
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1538 - accuracy: 0.9553
# Epoch 150/200
# 36/36 [==============================] - 1s 36ms/step - loss: 0.1850 - accuracy: 0.9330
# Epoch 151/200
# 36/36 [==============================] - 1s 40ms/step - loss: 0.1038 - accuracy: 0.9832
# Epoch 152/200
# 36/36 [==============================] - 2s 45ms/step - loss: 0.2229 - accuracy: 0.9274
# Epoch 153/200
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0804 - accuracy: 0.9777
# Epoch 154/200
# 36/36 [==============================] - 2s 46ms/step - loss: 0.2121 - accuracy: 0.9330
# Epoch 155/200
# 36/36 [==============================] - 1s 35ms/step - loss: 0.1495 - accuracy: 0.9777
# Epoch 156/200
# 36/36 [==============================] - 1s 33ms/step - loss: 0.1731 - accuracy: 0.9441
# Epoch 157/200
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1792 - accuracy: 0.9441
# Epoch 158/200
# 36/36 [==============================] - 1s 40ms/step - loss: 0.1356 - accuracy: 0.9777
# Epoch 159/200
# 36/36 [==============================] - 1s 36ms/step - loss: 0.1446 - accuracy: 0.9441
# Epoch 160/200
# 36/36 [==============================] - 1s 26ms/step - loss: 0.1178 - accuracy: 0.9553
# Epoch 161/200
# 36/36 [==============================] - 1s 37ms/step - loss: 0.1043 - accuracy: 0.9721
# Epoch 162/200
# 36/36 [==============================] - 1s 32ms/step - loss: 0.1862 - accuracy: 0.9274
# Epoch 163/200
# 36/36 [==============================] - 1s 34ms/step - loss: 0.1794 - accuracy: 0.9274
# Epoch 164/200
# 36/36 [==============================] - 1s 39ms/step - loss: 0.1730 - accuracy: 0.9385
# Epoch 165/200
# 36/36 [==============================] - 1s 26ms/step - loss: 0.1377 - accuracy: 0.9553
# Epoch 166/200
# 36/36 [==============================] - 1s 29ms/step - loss: 0.1496 - accuracy: 0.9665
# Epoch 167/200
# 36/36 [==============================] - 1s 32ms/step - loss: 0.1550 - accuracy: 0.9665
# Epoch 168/200
# 36/36 [==============================] - 1s 33ms/step - loss: 0.1510 - accuracy: 0.9609
# Epoch 169/200
# 36/36 [==============================] - 1s 31ms/step - loss: 0.1524 - accuracy: 0.9441
# Epoch 170/200
# 36/36 [==============================] - 1s 35ms/step - loss: 0.1716 - accuracy: 0.9441
# Epoch 171/200
# 36/36 [==============================] - 1s 29ms/step - loss: 0.1246 - accuracy: 0.9609
# Epoch 172/200
# 36/36 [==============================] - 1s 27ms/step - loss: 0.1287 - accuracy: 0.9441
# Epoch 173/200
# 36/36 [==============================] - 1s 38ms/step - loss: 0.1336 - accuracy: 0.9441
# Epoch 174/200
# 36/36 [==============================] - 1s 31ms/step - loss: 0.1794 - accuracy: 0.9218
# Epoch 175/200
# 36/36 [==============================] - 1s 29ms/step - loss: 0.1730 - accuracy: 0.9385
# Epoch 176/200
# 36/36 [==============================] - 1s 38ms/step - loss: 0.1927 - accuracy: 0.9330
# Epoch 177/200
# 36/36 [==============================] - 1s 23ms/step - loss: 0.1208 - accuracy: 0.9665
# Epoch 178/200
# 36/36 [==============================] - 1s 31ms/step - loss: 0.1430 - accuracy: 0.9497
# Epoch 179/200
# 36/36 [==============================] - 1s 40ms/step - loss: 0.1194 - accuracy: 0.9777
# Epoch 180/200
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2246 - accuracy: 0.9162
# Epoch 181/200
# 36/36 [==============================] - 2s 55ms/step - loss: 0.1323 - accuracy: 0.9665
# Epoch 182/200
# 36/36 [==============================] - 1s 28ms/step - loss: 0.1248 - accuracy: 0.9609
# Epoch 183/200
# 36/36 [==============================] - 1s 26ms/step - loss: 0.2044 - accuracy: 0.9385
# Epoch 184/200
# 36/36 [==============================] - 2s 61ms/step - loss: 0.1374 - accuracy: 0.9441
# Epoch 185/200
# 36/36 [==============================] - 2s 66ms/step - loss: 0.1694 - accuracy: 0.9553
# Epoch 186/200
# 36/36 [==============================] - 1s 39ms/step - loss: 0.1862 - accuracy: 0.9330
# Epoch 187/200
# 36/36 [==============================] - 4s 100ms/step - loss: 0.1021 - accuracy: 0.9721
# Epoch 188/200
# 36/36 [==============================] - 2s 53ms/step - loss: 0.1381 - accuracy: 0.9609
# Epoch 189/200
# 36/36 [==============================] - 3s 62ms/step - loss: 0.0909 - accuracy: 0.9777
# Epoch 190/200
# 36/36 [==============================] - 3s 80ms/step - loss: 0.1342 - accuracy: 0.9609
# Epoch 191/200
# 36/36 [==============================] - 3s 88ms/step - loss: 0.1685 - accuracy: 0.9441
# Epoch 192/200
# 36/36 [==============================] - 1s 38ms/step - loss: 0.1409 - accuracy: 0.9441
# Epoch 193/200
# 36/36 [==============================] - 3s 83ms/step - loss: 0.0847 - accuracy: 0.9721
# Epoch 194/200
# 36/36 [==============================] - 2s 59ms/step - loss: 0.1480 - accuracy: 0.9497
# Epoch 195/200
# 36/36 [==============================] - 3s 99ms/step - loss: 0.1232 - accuracy: 0.9609
# Epoch 196/200
# 36/36 [==============================] - 3s 73ms/step - loss: 0.1019 - accuracy: 0.9777
# Epoch 197/200
# 36/36 [==============================] - 2s 64ms/step - loss: 0.1145 - accuracy: 0.9665
# Epoch 198/200
# 36/36 [==============================] - 2s 53ms/step - loss: 0.1340 - accuracy: 0.9777
# Epoch 199/200
# 36/36 [==============================] - 2s 67ms/step - loss: 0.1517 - accuracy: 0.9441
# Epoch 200/200
# 36/36 [==============================] - 2s 51ms/step - loss: 0.1050 - accuracy: 0.9609

# %%
# Save the model
model.save('GYM_model.h5')
print("Model created and saved successfully!")
# Out:
# Model created and saved successfully!
